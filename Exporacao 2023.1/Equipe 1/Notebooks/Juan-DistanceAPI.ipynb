# %%
import dotenv
import requests
import pandas as pd
from tqdm.notebook import tqdm

# %%
dotenv.load_dotenv(dotenv.find_dotenv())

API = 'ArqoxmdG7ATOYJnTOg12Mg4kF5-yLopfrtbVVJwiw1gxwW-Noi6HS_kliMOH9lc8'

# %%
df = pd.read_parquet("../Dados/BikeData-Processed.parquet")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   duracao_viagem            1000000 non-null  int64
#  1   inicio_viagem             1000000 non-null  datetime64[ns]
#  2   fim_viagem                1000000 non-null  datetime64[ns]
#  3   id_estacao_inicio         999927 non-null   Int64
#  4   nome_estacao_inicio       999927 non-null   category
#  5   estacao_inicio_latitude   1000000 non-null  float64
#  6   estacao_inicio_longitude  1000000 non-null  float64
#  7   id_estacao_fim            999927 non-null   Int64
#  8   nome_estacao_fim          999927 non-null   category
#  9   estacao_fim_latitude      1000000 non-null  float64
#  10  estacao_fim_longitude     1000000 non-null  float64
#  11  id_bike                   1000000 non-null  int64
# ...

# %%
df.head()
# Out:
#    duracao_viagem           inicio_viagem              fim_viagem  \
# 0             882 2018-11-25 18:21:38.774 2018-11-25 18:36:21.472
# 1             669 2018-08-13 18:25:50.544 2018-08-13 18:36:59.968
# 2             521 2018-12-18 20:12:15.062 2018-12-18 20:20:57.017
# 3             270 2018-05-18 14:23:52.105 2018-05-18 14:28:22.491
# 4             441 2018-08-14 19:00:15.867 2018-08-14 19:07:37.052
#
#    id_estacao_inicio         nome_estacao_inicio  estacao_inicio_latitude  \
# 0                423             W 54 St & 9 Ave                40.765849
# 1               3467  W Broadway & Spring Street                40.724947
# 2                411           E 6 St & Avenue D                40.722281
# 3                437     Macon St & Nostrand Ave                40.680983
# 4                519       Pershing Square North                40.751873
#
#    estacao_inicio_longitude  id_estacao_fim          nome_estacao_fim  \
# ...

# %%
(
    df
    .query("id_estacao_inicio.isnull() and (nome_estacao_inicio.isnull()) and not((id_estacao_fim.isnull()) and (nome_estacao_fim.isnull()))")
)
# Out:
# Empty DataFrame
# Columns: [duracao_viagem, inicio_viagem, fim_viagem, id_estacao_inicio, nome_estacao_inicio, estacao_inicio_latitude, estacao_inicio_longitude, id_estacao_fim, nome_estacao_fim, estacao_fim_latitude, estacao_fim_longitude, id_bike, tipo_usuario, ano_nascimento, genero]
# Index: []

# %%
(
    df
    .query("id_estacao_fim.isnull() and (nome_estacao_fim.isnull())")
)
# Out:
# Empty DataFrame
# Columns: [duracao_viagem, inicio_viagem, fim_viagem, id_estacao_inicio, nome_estacao_inicio, estacao_inicio_latitude, estacao_inicio_longitude, id_estacao_fim, nome_estacao_fim, estacao_fim_latitude, estacao_fim_longitude, id_bike, tipo_usuario, ano_nascimento, genero]
# Index: []
